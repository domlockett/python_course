# %% [markdown]
# # Activity 4.2: Multivariate regression
# - This assignment will closely reflect the lecture, except in this instance we will look at cardiovascular prices in the four cities previously analyzed.
#
# - During and/or (necessarily) after you have finished this activity be sure to commit and push using GitHub Desktop.
#
# - Feel free to look back on the lecture/slides and use search engines for help.
#
# - **If you have any questions over the course of this activity, please post them to the 'Day 4 Lecture Questions' assignment on the Canvas course page.**

# %% [markdown]
# ## 1. Adding information to our data
#
# - Import the relevant packages.
# - Import the `cardio.csv` file and name the dataframe `cardio`
# - Import the `facility_demos_cardio.csv` file and name it demos.
# - Add the demographics of the facility's zip code.
# - The `facility_demos` file contains the following variables:
#     - **population** = Total population in the zip code of the clinic.
#     - **pct_middle_aged** = Percent of total population 45- 64 years in the zip code of the clinic.
#     - **pct_senior** = Percent of total population 65 years and over in the zip code of the clinic.
#     - **pct_male** = Percent male population in the zip code of the clinic.
#     - **pct_white** = Percent white in the zip code of the clinic.
#     - **pct_black** =  Percent black or African American in the zip code of the clinic.
#     - **pct_non_rel** = Percent in households with nonrelatives in the zip code of the clinic.
#     - **pct_vacant** = Percent vacant housing units in the zip code of the clinic.
# - Merge the two datasets and name this new dataframe `cardio2`.
# - Display your new datset.

# %%
import pandas as pd
cardio = pd.read_csv('cardio.csv')
demos = pd.read_csv('facility_demos_cardio.csv')
cardio2 = pd.merge(cardio,demos)
cardio2
# Out:
#        price                            facility  \
# 0       90.0             Advanced Cardiology LLC
# 1      110.0                Lenox Hill Radiology
# 2      150.0                 Staten Island Heart
# 3      150.0                 Staten Island Heart
# 4      150.0                 Staten Island Heart
# ..       ...                                 ...
# 163   7106.0    Baylor University Medical Center
# 164   7106.0  Baylor Scott and White Lake Pointe
# 165   8217.0   Baylor Scott and White All Saints
# 166  12530.0   Baylor Scott and White Waxahachie
# 167  13224.0  Texas Health Presbyterian Rockwall
#
#                                             address       condition    zip  \
# 0           117 Seber Rd., Ste. 1B, Hackettstown NJ  cardiovascular  10001
# 1    80-02 Kew Gardens Rd., Ste. L1, Kew Gardens NY  cardiovascular  10001
# 2      501 Seaview Ave., Ste. 300, Staten Island NY  cardiovascular  10001
# 3      501 Seaview Ave., Ste. 300, Staten Island NY  cardiovascular  10001
# 4      501 Seaview Ave., Ste. 300, Staten Island NY  cardiovascular  10001
# ..                                              ...             ...    ...
# 163                     3500 Gaston Ave., Dallas TX  cardiovascular  75001
# 164                 6800 Scenic Dr., Lake Pointe TX  cardiovascular  75001
# 165                    1400 8th Ave., Fort Worth TX  cardiovascular  75001
# 166                    2400 N. I-35E, Waxahachie TX  cardiovascular  75001
# 167                   3150 Horizon Rd., Rockwall TX  cardiovascular  75001
#
#      radius      city  population  pct_middle_aged  pct_senior  pct_male  \
# 0        50  New York       29849             28.1        13.8      47.6
# 1        50  New York       19341             26.3        13.9      47.9
# 2        50  New York       41749             28.2        13.0      48.6
# 3        50  New York       41749             28.2        13.0      48.6
# 4        50  New York       41749             28.2        13.0      48.6
# ..      ...       ...         ...              ...         ...       ...
# 163      50    Dallas        2770             20.6         9.2      53.4
# 164      50    Dallas       24712             32.4         8.7      49.2
# 165      50    Dallas       17446             23.6        11.4      50.1
# 166      50    Dallas       37966             24.5        11.0      49.0
# 167      50    Dallas       27986             27.3         8.6      49.8
#
#      pct_white  pct_black  pct_non_rel  pct_vacant
# 0         86.2        3.0          4.5         6.1
# 1         62.3        7.3          6.5         6.4
# 2         76.2        4.4          3.7         6.4
# 3         76.2        4.4          3.7         6.4
# 4         76.2        4.4          3.7         6.4
# ..         ...        ...          ...         ...
# 163       51.2       16.8          9.8        14.9
# 164       75.5       11.2          3.2         3.6
# 165       30.2       47.1          6.3        16.6
# 166       77.9       10.7          4.5         8.5
# 167       82.3        5.5          3.1         5.5
#
# [168 rows x 15 columns]

# %% [markdown]
# ## 2. Remove 'bad' data.
# - Remove instances where the price is 0
# - Be sure to overwrite your `cardio` object.
# - Display your updated dataframe.

# %%
cardio = cardio[cardio.price != 0]
cardio
# Out:
#        price                            facility  \
# 0       90.0             Advanced Cardiology LLC
# 1      110.0                Lenox Hill Radiology
# 2      150.0                 Staten Island Heart
# 3      150.0   Mt. Sinai Riverside Medical Group
# 4      150.0   Mt. Sinai Riverside Medical Group
# ..       ...                                 ...
# 101   7106.0    Baylor University Medical Center
# 102   7106.0  Baylor Scott and White Lake Pointe
# 103   8217.0   Baylor Scott and White All Saints
# 104  12530.0   Baylor Scott and White Waxahachie
# 105  13224.0  Texas Health Presbyterian Rockwall
#
#                                             address       condition    zip  \
# 0           117 Seber Rd., Ste. 1B, Hackettstown NJ  cardiovascular  10001
# 1    80-02 Kew Gardens Rd., Ste. L1, Kew Gardens NY  cardiovascular  10001
# 2      501 Seaview Ave., Ste. 300, Staten Island NY  cardiovascular  10001
# 3                      1010 N. Broadway, Yonkers NY  cardiovascular  10001
# 4                      1010 N. Broadway, Yonkers NY  cardiovascular  10001
# ..                                              ...             ...    ...
# 101                     3500 Gaston Ave., Dallas TX  cardiovascular  75001
# 102                 6800 Scenic Dr., Lake Pointe TX  cardiovascular  75001
# 103                    1400 8th Ave., Fort Worth TX  cardiovascular  75001
# 104                    2400 N. I-35E, Waxahachie TX  cardiovascular  75001
# 105                   3150 Horizon Rd., Rockwall TX  cardiovascular  75001
#
#      radius      city
# 0        50  New York
# 1        50  New York
# 2        50  New York
# 3        50  New York
# 4        50  New York
# ..      ...       ...
# 101      50    Dallas
# 102      50    Dallas
# 103      50    Dallas
# 104      50    Dallas
# 105      50    Dallas
#
# [106 rows x 7 columns]

# %% [markdown]
# ## 3. Explore the new data.
# - Import the `seaborn` package.
# - Use the `distplot` attribute of the `seaborn` package to look at the distribution of the population.

# %%
import seaborn as sns
sns.distplot(cardio2['population'])

# %% [markdown]
# ## 4. Explore the new data.
#
# - Use the `distplot` attribute of the `seaborn` package to look at the distribution of the `pct_middle_aged`.

# %%
sns.distplot(cardio2['pct_middle_aged'])

# %% [markdown]
# ## 5. Look at regression plot
#
# - Use the `lmplot` attribute of `sns` to explore how the percentage of the population which are senior citizens impacts the prices of cardiovascular healthcare.

# %%
sns.lmplot(data=cardio2, x='pct_senior', y='price')

# %% [markdown]
# ## 6. Run your multivariate regression
# - Load in the appropriate
# - Using whichever variables you feel would be most suited for this analysis, run a regression.
# - *Hint: you can use the call `list(cardio2.columns) to look at all of your variables.

# %%
#We can do a linear regression with C() denoting that our data is categorical
import statsmodels.formula.api as smf

lm = smf.ols("price ~ C(city, Treatment(reference='New York'))+  pct_middle_aged+pct_senior+pct_male+pct_white+pct_black+pct_non_rel+pct_vacant", data = cardio2).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.200
# Model:                            OLS   Adj. R-squared:                  0.149
# Method:                 Least Squares   F-statistic:                     3.924
# Date:                Sat, 30 May 2020   Prob (F-statistic):           8.76e-05
# Time:                        17:50:30   Log-Likelihood:                -1477.2
# No. Observations:                 168   AIC:                             2976.
# Df Residuals:                     157   BIC:                             3011.
# Df Model:                          10
# Covariance Type:            nonrobust
# =============================================================================================================================
#                                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------
# Intercept                                                  -880.4790   1163.632     -0.757      0.450   -3178.873    1417.915
# C(city, Treatment(reference='New York'))[T.Dallas]         2072.6363    394.168      5.258      0.000    1294.081    2851.192
# C(city, Treatment(reference='New York'))[T.Miami]           513.0812    471.957      1.087      0.279    -419.123    1445.285
# C(city, Treatment(reference='New York'))[T.San Francisco]   329.8170    469.337      0.703      0.483    -597.212    1256.846
# pct_middle_aged                                             -35.8235     48.274     -0.742      0.459    -131.174      59.527
# pct_senior                                                  -10.4820     32.578     -0.322      0.748     -74.829      53.865
# pct_male                                                     32.7071     37.223      0.879      0.381     -40.815     106.230
# pct_white                                                    15.8247     12.566      1.259      0.210      -8.997      40.646
# pct_black                                                     1.1094     16.182      0.069      0.945     -30.854      33.073
# pct_non_rel                                                 -27.8131     53.768     -0.517      0.606    -134.014      78.388
# pct_vacant                                                  -15.2360     21.688     -0.703      0.483     -58.073      27.601
# ==============================================================================
# Omnibus:                      158.428   Durbin-Watson:                   0.135
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2795.366
# Skew:                           3.495   Prob(JB):                         0.00
# Kurtosis:                      21.721   Cond. No.                         812.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
