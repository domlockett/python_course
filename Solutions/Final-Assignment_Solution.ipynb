# %% [markdown]
# # Final assignment
#
# - The final assignment is a problem set in which I try to expose you to some issues you might experience in the real world. The goal is to compile data and understand any relationship between population, population density and the spread of COVID-19.

# %% [markdown]
# ## 1. Load in basic packages and  import the covid data.
# - Import the `NumPy` and `pandas` packages.
# - Import the COVID-19 data from the following link:
#     - - Import the COVID-19 data from the following link: https://raw.githubusercontent.com/nytimes/covid-19-data/master/live/us-counties.csv
#     - This data was compiled by [New York Times](https://github.com/nytimes).
# - Import this file as a variable named `covid`

# %%
import pandas as pd
import numpy as np
covid = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/live/us-counties.csv')

# %% [markdown]
# ## Explore the data.
# - Dislay the columns in the dataframe as a list.
# - Make a variable `tableCases` in which you use the `pandas` attribute `pivot_table` to display the total number of cases in each state using the additional argument `aggfunc = np.sum`.
# - Make a variable `tableDeaths` in which you use the `pandas` attribute `pivot_table` to display the average number of deaths by state using the additional argument `aggfunc = np.sum`.
# - use `print()` to display both of these tables.

# %%
# Display the columns below this line:

# %%
tableCases = pd.pivot_table(covid, index = 'state', values = 'cases', aggfunc = np.sum)
tableDeaths=pd.pivot_table(covid, index = 'state', values = 'deaths', aggfunc = np.sum)
print(tableCases)
print(tableDeaths)
# Out:
#                            cases
# state
# Alabama                    26272
# Alaska                       734
# Arizona                    36813
# Arkansas                   12501
# California                154200
# Colorado                   29115
# Connecticut                45088
# Delaware                   10340
# District of Columbia        9799
# Florida                    77318
# Georgia                    54874
# Guam                        1154
# Hawaii                       716
# Idaho                       3413
# Illinois                  133727
# Indiana                    41422
# Iowa                       24047
# Kansas                     11497
# Kentucky                   12707
# Louisiana                  47284
# Maine                       2810
# Maryland                   62584
# Massachusetts             105603
# Michigan                   66246
# Minnesota                  30724
# Mississippi                19799
# Missouri                   16496
# Montana                      609
# Nebraska                   16803
# Nevada                     11283
# New Hampshire               5318
# New Jersey                167103
# New Mexico                  9723
# New York                  388719
# North Carolina             45102
# North Dakota                3104
# Northern Mariana Islands      30
# Ohio                       41576
# Oklahoma                    8417
# Oregon                      5702
# Pennsylvania               83687
# Puerto Rico                 5890
# Rhode Island               16093
# South Carolina             18795
# South Dakota                5928
# Tennessee                  30599
# Texas                      90307
# Utah                       14313
# Vermont                     1128
# Virgin Islands                72
# Virginia                   54886
# Washington                 27203
# West Virginia               2298
# Wisconsin                  22867
# Wyoming                     1060
#                            deaths
# state
# Alabama                     774.0
# Alaska                       10.0
# Arizona                    1202.0
# Arkansas                    179.0
# California                 5093.0
# Colorado                   1599.0
# Connecticut                4201.0
# Delaware                    423.0
# District of Columbia        515.0
# Florida                    2937.0
# Georgia                    2416.0
# Guam                          6.0
# Hawaii                       17.0
# Idaho                        88.0
# Illinois                   6512.0
# Indiana                    2433.0
# Iowa                        653.0
# Kansas                      246.0
# Kentucky                    519.0
# Louisiana                  3018.0
# Maine                       101.0
# Maryland                   2947.0
# Massachusetts              7624.0
# Michigan                   6020.0
# Minnesota                  1335.0
# Mississippi                 895.0
# Missouri                    890.0
# Montana                      19.0
# Nebraska                    221.0
# Nevada                      465.0
# New Hampshire               320.0
# New Jersey                12676.0
# New Mexico                  435.0
# New York                  30645.0
# North Carolina             1144.0
# North Dakota                 77.0
# Northern Mariana Islands      2.0
# Ohio                       2573.0
# Oklahoma                    359.0
# Oregon                      180.0
# Pennsylvania               6307.0
# Puerto Rico                   0.0
# Rhode Island                851.0
# South Carolina              600.0
# South Dakota                 75.0
# Tennessee                   467.0
# Texas                      2000.0
# Utah                        139.0
# Vermont                      55.0
# Virgin Islands                6.0
# Virginia                   1552.0
# Washington                 1220.0
# West Virginia                88.0
# Wisconsin                   696.0
# Wyoming                      18.0

# %% [markdown]
# ## Understanding `pivot_table` more.
# - Run the function `.columns` on your two tables.
#     - Notice how 'cases' and 'deaths' are the only columns displayed. This is because 'state' is used as index.
# - Run the function `.reset_index()` on both `tableCases` and `tableDeaths` and update these variables.
# - Now look at your tables again.

# %%
# Review the columns below this line:

# %%
tableCases = tableCases.reset_index()
tableDeaths = tableDeaths.reset_index()
print(tableCases)
print(tableDeaths)
# Out:
#                        state   cases
# 0                    Alabama   26272
# 1                     Alaska     734
# 2                    Arizona   36813
# 3                   Arkansas   12501
# 4                 California  154200
# 5                   Colorado   29115
# 6                Connecticut   45088
# 7                   Delaware   10340
# 8       District of Columbia    9799
# 9                    Florida   77318
# 10                   Georgia   54874
# 11                      Guam    1154
# 12                    Hawaii     716
# 13                     Idaho    3413
# 14                  Illinois  133727
# 15                   Indiana   41422
# 16                      Iowa   24047
# 17                    Kansas   11497
# 18                  Kentucky   12707
# 19                 Louisiana   47284
# 20                     Maine    2810
# 21                  Maryland   62584
# 22             Massachusetts  105603
# 23                  Michigan   66246
# 24                 Minnesota   30724
# 25               Mississippi   19799
# 26                  Missouri   16496
# 27                   Montana     609
# 28                  Nebraska   16803
# 29                    Nevada   11283
# 30             New Hampshire    5318
# 31                New Jersey  167103
# 32                New Mexico    9723
# 33                  New York  388719
# 34            North Carolina   45102
# 35              North Dakota    3104
# 36  Northern Mariana Islands      30
# 37                      Ohio   41576
# 38                  Oklahoma    8417
# 39                    Oregon    5702
# 40              Pennsylvania   83687
# 41               Puerto Rico    5890
# 42              Rhode Island   16093
# 43            South Carolina   18795
# 44              South Dakota    5928
# 45                 Tennessee   30599
# 46                     Texas   90307
# 47                      Utah   14313
# 48                   Vermont    1128
# 49            Virgin Islands      72
# 50                  Virginia   54886
# 51                Washington   27203
# 52             West Virginia    2298
# 53                 Wisconsin   22867
# 54                   Wyoming    1060
#                        state   deaths
# 0                    Alabama    774.0
# 1                     Alaska     10.0
# 2                    Arizona   1202.0
# 3                   Arkansas    179.0
# 4                 California   5093.0
# 5                   Colorado   1599.0
# 6                Connecticut   4201.0
# 7                   Delaware    423.0
# 8       District of Columbia    515.0
# 9                    Florida   2937.0
# 10                   Georgia   2416.0
# 11                      Guam      6.0
# 12                    Hawaii     17.0
# 13                     Idaho     88.0
# 14                  Illinois   6512.0
# 15                   Indiana   2433.0
# 16                      Iowa    653.0
# 17                    Kansas    246.0
# 18                  Kentucky    519.0
# 19                 Louisiana   3018.0
# 20                     Maine    101.0
# 21                  Maryland   2947.0
# 22             Massachusetts   7624.0
# 23                  Michigan   6020.0
# 24                 Minnesota   1335.0
# 25               Mississippi    895.0
# 26                  Missouri    890.0
# 27                   Montana     19.0
# 28                  Nebraska    221.0
# 29                    Nevada    465.0
# 30             New Hampshire    320.0
# 31                New Jersey  12676.0
# 32                New Mexico    435.0
# 33                  New York  30645.0
# 34            North Carolina   1144.0
# 35              North Dakota     77.0
# 36  Northern Mariana Islands      2.0
# 37                      Ohio   2573.0
# 38                  Oklahoma    359.0
# 39                    Oregon    180.0
# 40              Pennsylvania   6307.0
# 41               Puerto Rico      0.0
# 42              Rhode Island    851.0
# 43            South Carolina    600.0
# 44              South Dakota     75.0
# 45                 Tennessee    467.0
# 46                     Texas   2000.0
# 47                      Utah    139.0
# 48                   Vermont     55.0
# 49            Virgin Islands      6.0
# 50                  Virginia   1552.0
# 51                Washington   1220.0
# 52             West Virginia     88.0
# 53                 Wisconsin    696.0
# 54                   Wyoming     18.0

# %% [markdown]
# ## Merge your two dataframes.
# - Create a new variable `casesDeaths` which merges the two tables you have created.
#
# - Display this new dataframe.

# %%
casesDeaths = pd.merge(tableCases, tableDeaths)
casesDeaths
# Out:
#                        state   cases   deaths
# 0                    Alabama   26272    774.0
# 1                     Alaska     734     10.0
# 2                    Arizona   36813   1202.0
# 3                   Arkansas   12501    179.0
# 4                 California  154200   5093.0
# 5                   Colorado   29115   1599.0
# 6                Connecticut   45088   4201.0
# 7                   Delaware   10340    423.0
# 8       District of Columbia    9799    515.0
# 9                    Florida   77318   2937.0
# 10                   Georgia   54874   2416.0
# 11                      Guam    1154      6.0
# 12                    Hawaii     716     17.0
# 13                     Idaho    3413     88.0
# 14                  Illinois  133727   6512.0
# 15                   Indiana   41422   2433.0
# 16                      Iowa   24047    653.0
# 17                    Kansas   11497    246.0
# 18                  Kentucky   12707    519.0
# 19                 Louisiana   47284   3018.0
# 20                     Maine    2810    101.0
# 21                  Maryland   62584   2947.0
# 22             Massachusetts  105603   7624.0
# 23                  Michigan   66246   6020.0
# 24                 Minnesota   30724   1335.0
# 25               Mississippi   19799    895.0
# 26                  Missouri   16496    890.0
# 27                   Montana     609     19.0
# 28                  Nebraska   16803    221.0
# 29                    Nevada   11283    465.0
# 30             New Hampshire    5318    320.0
# 31                New Jersey  167103  12676.0
# 32                New Mexico    9723    435.0
# 33                  New York  388719  30645.0
# 34            North Carolina   45102   1144.0
# 35              North Dakota    3104     77.0
# 36  Northern Mariana Islands      30      2.0
# 37                      Ohio   41576   2573.0
# 38                  Oklahoma    8417    359.0
# 39                    Oregon    5702    180.0
# 40              Pennsylvania   83687   6307.0
# 41               Puerto Rico    5890      0.0
# 42              Rhode Island   16093    851.0
# 43            South Carolina   18795    600.0
# 44              South Dakota    5928     75.0
# 45                 Tennessee   30599    467.0
# 46                     Texas   90307   2000.0
# 47                      Utah   14313    139.0
# 48                   Vermont    1128     55.0
# 49            Virgin Islands      72      6.0
# 50                  Virginia   54886   1552.0
# 51                Washington   27203   1220.0
# 52             West Virginia    2298     88.0
# 53                 Wisconsin   22867    696.0
# 54                   Wyoming    1060     18.0

# %% [markdown]
# ## Plot some data.
#
# - Load in the `matplotlib.pyplot as plt`.
# - Conduct the following steps in order:
#     - Using the `casesDeaths` variable run `plot.bar(x= ,y=)`.
#     - Put 'state' in `x` and `['cases','deaths']` in `y`.
#     - Now from `plt` change use the attribute `.ylabel` to `Total` and `.title` to 'COVID-19 Deaths and Cases by State'

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

casesDeaths.plot.bar(x = 'state',y = ['cases','deaths'])
plt.ylabel("Total") 
plt.title("COVID-19 Deaths and Cases by State")
# Out:
# Text(0.5, 1.0, 'COVID-19 Deaths and Cases by State')

# %% [markdown]
# ## Plot a subset.
# - Now subset the `casesDeaths` variable to a new variable `myFive` and select five states you are interested in and plot those as you plotted `casesDeaths` above.
#     - You can use brackets to subset standard and within the brackets use the `.isin()` function of the `.state` column.

# %%
myFive = casesDeaths[casesDeaths.state.isin(['Missouri','Indiana','Illinois','Kentucky','Ohio'])]
myFive.plot.bar(x = 'state',y = ['cases','deaths'])
plt.ylabel("Total") 
plt.title("COVID-19 Deaths and Cases by State")
# Out:
# Text(0.5, 1.0, 'COVID-19 Deaths and Cases by State')

# %%
list(covid.columns)
# Out:
# ['date',
#  'county',
#  'state',
#  'fips',
#  'cases',
#  'deaths',
#  'confirmed_cases',
#  'confirmed_deaths',
#  'probable_cases',
#  'probable_deaths']

# %%
list(covid.county[covid.state == 'Missouri'])
# Out:
# ['Adair',
#  'Andrew',
#  'Atchison',
#  'Audrain',
#  'Barry',
#  'Barton',
#  'Bates',
#  'Benton',
#  'Bollinger',
#  'Boone',
#  'Buchanan',
#  'Butler',
#  'Caldwell',
#  'Callaway',
#  'Camden',
#  'Cape Girardeau',
#  'Carroll',
#  'Carter',
#  'Cass',
#  'Cedar',
#  'Chariton',
#  'Christian',
#  'Clark',
#  'Clay',
#  'Clinton',
#  'Cole',
#  'Cooper',
#  'Crawford',
#  'Dallas',
#  'Daviess',
#  'DeKalb',
#  'Dent',
#  'Douglas',
#  'Dunklin',
#  'Franklin',
#  'Gasconade',
#  'Gentry',
#  'Greene',
#  'Grundy',
#  'Harrison',
#  'Henry',
#  'Holt',
#  'Howard',
#  'Howell',
#  'Iron',
#  'Jackson',
#  'Jasper',
#  'Jefferson',
#  'Johnson',
#  'Kansas City',
#  'Knox',
#  'Laclede',
#  'Lafayette',
#  'Lawrence',
#  'Lewis',
#  'Lincoln',
#  'Linn',
#  'Livingston',
#  'Macon',
#  'Madison',
#  'Maries',
#  'Marion',
#  'McDonald',
#  'Mercer',
#  'Miller',
#  'Mississippi',
#  'Moniteau',
#  'Monroe',
#  'Montgomery',
#  'Morgan',
#  'New Madrid',
#  'Newton',
#  'Nodaway',
#  'Oregon',
#  'Osage',
#  'Pemiscot',
#  'Perry',
#  'Pettis',
#  'Phelps',
#  'Pike',
#  'Platte',
#  'Polk',
#  'Pulaski',
#  'Putnam',
#  'Ralls',
#  'Randolph',
#  'Ray',
#  'Reynolds',
#  'Ripley',
#  'Saline',
#  'Schuyler',
#  'Scotland',
#  'Scott',
#  'Shannon',
#  'Shelby',
#  'St. Charles',
#  'St. Clair',
#  'St. Francois',
#  'St. Louis',
#  'St. Louis city',
#  'Ste. Genevieve',
#  'Stoddard',
#  'Stone',
#  'Sullivan',
#  'Taney',
#  'Texas',
#  'Vernon',
#  'Warren',
#  'Washington',
#  'Webster',
#  'Worth',
#  'Wright']

# %% [markdown]
# ## Load the `mo_dict` data below.
# - Run the code below to create the `mo_dict` object.

# %%
mo_dict = {'001': {'county': 'Adair County', 'population': 25607, 'area': 568.0}, '003': {'county': 'Andrew County', 'population': 17291, 'area': 435.0}, '005': {'county': 'Atchison County', 'population': 5685, 'area': 545.0},
 '007': {'county': 'Audrain County', 'population': 25529, 'area': 693.0}, '009': {'county': 'Barry County', 'population': 35597, 'area': 779.0}, '011': {'county': 'Barton County', 'population': 12402, 'area': 594.0},
 '013': {'county': 'Bates County', 'population': 17049, 'area': 848.0}, '015': {'county': 'Benton County', 'population': 19056, 'area': 706.0}, '017': {'county': 'Bollinger County', 'population': 12363, 'area': 621.0},
 '019': {'county': 'Boone County', 'population': 162642, 'area': 685.0}, '021': {'county': 'Buchanan County', 'population': 89201, 'area': 410.0}, '023': {'county': 'Butler County', 'population': 42794, 'area': 698.0},
 '025': {'county': 'Caldwell County', 'population': 9424, 'area': 429.0}, '027': {'county': 'Callaway County', 'population': 44332, 'area': 839.0}, '029': {'county': 'Camden County', 'population': 44002, 'area': 655.0},
 '031': {'county': 'Cape Girardeau County',  'population': 75674,  'area': 579.0}, '033': {'county': 'Carroll County', 'population': 9295, 'area': 695.0}, '035': {'county': 'Carter County', 'population': 6265, 'area': 508.0},
 '037': {'county': 'Cass County', 'population': 99478, 'area': 699.0}, '039': {'county': 'Cedar County', 'population': 13982, 'area': 476.0}, '041': {'county': 'Chariton County', 'population': 7831, 'area': 756.0},
 '043': {'county': 'Christian County', 'population': 77422, 'area': 563.0}, '045': {'county': 'Clark County', 'population': 7139, 'area': 507.0}, '047': {'county': 'Clay County', 'population': 221939, 'area': 396.0},
 '049': {'county': 'Clinton County', 'population': 20743, 'area': 419.0}, '051': {'county': 'Cole County', 'population': 75990, 'area': 392.0}, '053': {'county': 'Cooper County', 'population': 17601, 'area': 565.0},
 '055': {'county': 'Crawford County', 'population': 24696, 'area': 743.0}, '057': {'county': 'Dade County', 'population': 7883, 'area': 490.0}, '059': {'county': 'Dallas County', 'population': 16777, 'area': 542.0},
 '061': {'county': 'Daviess County', 'population': 8433, 'area': 567.0}, '063': {'county': 'DeKalb County', 'population': 12892, 'area': 424.0}, '065': {'county': 'Dent County', 'population': 15657, 'area': 754.0},
 '067': {'county': 'Douglas County', 'population': 13684, 'area': 815.0}, '069': {'county': 'Dunklin County', 'population': 31953, 'area': 546.0}, '071': {'county': 'Franklin County', 'population': 101492, 'area': 922.0},
 '073': {'county': 'Gasconade County', 'population': 15222, 'area': 520.0}, '075': {'county': 'Gentry County', 'population': 6738, 'area': 492.0}, '077': {'county': 'Greene County', 'population': 275174, 'area': 675.0},
 '079': {'county': 'Grundy County', 'population': 10261, 'area': 436.0}, '081': {'county': 'Harrison County', 'population': 8957, 'area': 725.0}, '083': {'county': 'Henry County', 'population': 22272, 'area': 702.0},
 '085': {'county': 'Hickory County', 'population': 9627, 'area': 399.0}, '087': {'county': 'Holt County', 'population': 4912, 'area': 462.0}, '089': {'county': 'Howard County', 'population': 10144, 'area': 466.0},
 '091': {'county': 'Howell County', 'population': 40400, 'area': 928.0}, '093': {'county': 'Iron County', 'population': 10630, 'area': 551.0}, '095': {'county': 'Jackson County', 'population': 674158, 'area': 605.0},
 '097': {'county': 'Jasper County', 'population': 117404, 'area': 640.0}, '099': {'county': 'Jefferson County', 'population': 218733, 'area': 657.0}, '101': {'county': 'Johnson County', 'population': 52595, 'area': 831.0},
 '103': {'county': 'Knox County', 'population': 4131, 'area': 506.0}, '105': {'county': 'Laclede County', 'population': 35571, 'area': 766.0}, '107': {'county': 'Lafayette County', 'population': 33381, 'area': 629.0},
 '109': {'county': 'Lawrence County', 'population': 38634, 'area': 613.0}, '111': {'county': 'Lewis County', 'population': 10211, 'area': 505.0}, '113': {'county': 'Lincoln County', 'population': 52566, 'area': 630.0},
 '115': {'county': 'Linn County', 'population': 12761, 'area': 620.0}, '117': {'county': 'Livingston County', 'population': 15195, 'area': 535.0}, '121': {'county': 'Macon County', 'population': 15566, 'area': 804.0},
 '123': {'county': 'Madison County', 'population': 12226, 'area': 497.0}, '125': {'county': 'Maries County', 'population': 9176, 'area': 528.0}, '127': {'county': 'Marion County', 'population': 28781, 'area': 438.0},
 '119': {'county': 'McDonald County', 'population': 23083, 'area': 540.0}, '129': {'county': 'Mercer County', 'population': 3785, 'area': 454.0}, '131': {'county': 'Miller County', 'population': 24748, 'area': 592.0},
 '133': {'county': 'Mississippi County', 'population': 14358, 'area': 413.0}, '135': {'county': 'Moniteau County', 'population': 15607, 'area': 417.0}, '137': {'county': 'Monroe County', 'population': 8840, 'area': 646.0},
 '139': {'county': 'Montgomery County', 'population': 12236, 'area': 539.0}, '141': {'county': 'Morgan County', 'population': 20565, 'area': 598.0}, '143': {'county': 'New Madrid County', 'population': 18956, 'area': 678.0},
 '145': {'county': 'Newton County', 'population': 58114, 'area': 626.0}, '147': {'county': 'Nodaway County', 'population': 23370, 'area': 877.0}, '149': {'county': 'Oregon County', 'population': 10881, 'area': 792.0},
 '151': {'county': 'Osage County', 'population': 13878, 'area': 606.0}, '153': {'county': 'Ozark County', 'population': 9723, 'area': 747.0}, '155': {'county': 'Pemiscot County', 'population': 18296, 'area': 493.0},
 '157': {'county': 'Perry County', 'population': 18971, 'area': 475.0}, '159': {'county': 'Pettis County', 'population': 42201, 'area': 685.0}, '161': {'county': 'Phelps County', 'population': 45156, 'area': 673.0},
 '163': {'county': 'Pike County', 'population': 18516, 'area': 673.0}, '165': {'county': 'Platte County', 'population': 89322, 'area': 420.0}, '167': {'county': 'Polk County', 'population': 31137, 'area': 637.0},
 '169': {'county': 'Pulaski County', 'population': 52274, 'area': 547.0}, '171': {'county': 'Putnam County', 'population': 4979, 'area': 518.0}, '173': {'county': 'Ralls County', 'population': 10167, 'area': 471.0},
 '175': {'county': 'Randolph County', 'population': 25414, 'area': 482.0}, '177': {'county': 'Ray County', 'population': 23494, 'area': 570.0}, '179': {'county': 'Reynolds County', 'population': 6696, 'area': 811.0},
 '181': {'county': 'Ripley County', 'population': 14100, 'area': 630.0}, '183': {'county': 'St. Charles County',  'population': 360485,  'area': 561.0}, '185': {'county': 'St. Clair County', 'population': 9805, 'area': 677.0},
 '187': {'county': 'St. Francois County',  'population': 65359,  'area': 450.0}, '189': {'county': 'St. Louis County', 'population': 1000438, 'area': 508.0}, '510': {'county': 'St. Louis city County', 'population': 319294, 'area': 61.9},
 '186': {'county': 'St. Genevieve County',  'population': 18145,  'area': 502.0}, '195': {'county': 'Saline County', 'population': 23370, 'area': 756.0}, '197': {'county': 'Schuyler County', 'population': 4431, 'area': 308.0},
 '199': {'county': 'Scotland County', 'population': 4843, 'area': 438.0}, '201': {'county': 'Scott County', 'population': 39191, 'area': 421.0}, '203': {'county': 'Shannon County', 'population': 8441, 'area': 1004.0},
 '205': {'county': 'Shelby County', 'population': 6373, 'area': 501.0}, '207': {'county': 'Stoddard County', 'population': 29968, 'area': 827.0}, '209': {'county': 'Stone County', 'population': 32202, 'area': 463.0},
 '211': {'county': 'Sullivan County', 'population': 6714, 'area': 651.0}, '213': {'county': 'Taney County', 'population': 51675, 'area': 632.0}, '215': {'county': 'Texas County', 'population': 26008, 'area': 1179.0},
 '217': {'county': 'Vernon County', 'population': 21159, 'area': 834.0}, '219': {'county': 'Warren County', 'population': 32513, 'area': 432.0}, '221': {'county': 'Washington County', 'population': 25195, 'area': 760.0},
 '223': {'county': 'Wayne County', 'population': 13521, 'area': 761.0}, '225': {'county': 'Webster County', 'population': 36202, 'area': 593.0}, '227': {'county': 'Worth County', 'population': 2171, 'area': 266.0},
 '229': {'county': 'Wright County', 'population': 18815, 'area': 682.0}}

# %% [markdown]
# ##  Change dictionary to panda
# - Take the `mo_dict` file and change it to a panda object named `mo_counties`
# - Transpose the data so that the `county population` and `area` are the columns and each county is a row.
# - Be sure to overwrite your panda file and display your updated (transposed) dataframe.

# %%
mo_counties = pd.DataFrame(mo_dict)
mo_counties = mo_counties.T
mo_counties
# Out:
#                 county population area
# 001       Adair County      25607  568
# 003      Andrew County      17291  435
# 005    Atchison County       5685  545
# 007     Audrain County      25529  693
# 009       Barry County      35597  779
# ..                 ...        ...  ...
# 221  Washington County      25195  760
# 223       Wayne County      13521  761
# 225     Webster County      36202  593
# 227       Worth County       2171  266
# 229      Wright County      18815  682
#
# [115 rows x 3 columns]

# %% [markdown]
# ## Look at the unique counties.
#
# - Look at the counties in your `mo_counties` data.
# - Display the number of unique counties in Missouri.

# %%
mo_counties.county.unique()
# Out:
# array(['Adair County', 'Andrew County', 'Atchison County',
#        'Audrain County', 'Barry County', 'Barton County', 'Bates County',
#        'Benton County', 'Bollinger County', 'Boone County',
#        'Buchanan County', 'Butler County', 'Caldwell County',
#        'Callaway County', 'Camden County', 'Cape Girardeau County',
#        'Carroll County', 'Carter County', 'Cass County', 'Cedar County',
#        'Chariton County', 'Christian County', 'Clark County',
#        'Clay County', 'Clinton County', 'Cole County', 'Cooper County',
#        'Crawford County', 'Dade County', 'Dallas County',
#        'Daviess County', 'DeKalb County', 'Dent County', 'Douglas County',
#        'Dunklin County', 'Franklin County', 'Gasconade County',
#        'Gentry County', 'Greene County', 'Grundy County',
#        'Harrison County', 'Henry County', 'Hickory County', 'Holt County',
#        'Howard County', 'Howell County', 'Iron County', 'Jackson County',
#        'Jasper County', 'Jefferson County', 'Johnson County',
#        'Knox County', 'Laclede County', 'Lafayette County',
#        'Lawrence County', 'Lewis County', 'Lincoln County', 'Linn County',
#        'Livingston County', 'Macon County', 'Madison County',
#        'Maries County', 'Marion County', 'McDonald County',
#        'Mercer County', 'Miller County', 'Mississippi County',
#        'Moniteau County', 'Monroe County', 'Montgomery County',
#        'Morgan County', 'New Madrid County', 'Newton County',
#        'Nodaway County', 'Oregon County', 'Osage County', 'Ozark County',
#        'Pemiscot County', 'Perry County', 'Pettis County',
#        'Phelps County', 'Pike County', 'Platte County', 'Polk County',
#        'Pulaski County', 'Putnam County', 'Ralls County',
#        'Randolph County', 'Ray County', 'Reynolds County',
#        'Ripley County', 'St. Charles County', 'St. Clair County',
#        'St. Francois County', 'St. Louis County', 'St. Louis city County',
#        'St. Genevieve County', 'Saline County', 'Schuyler County',
#        'Scotland County', 'Scott County', 'Shannon County',
#        'Shelby County', 'Stoddard County', 'Stone County',
#        'Sullivan County', 'Taney County', 'Texas County', 'Vernon County',
#        'Warren County', 'Washington County', 'Wayne County',
#        'Webster County', 'Worth County', 'Wright County'], dtype=object)

# %%
covid.county[covid.county == "St. Louis city"]
# Out:
# 1558    St. Louis city
# Name: county, dtype: object

# %% [markdown]
# ## Edit data for merge.
#
# - Notice that the `covid` data does not include the word 'county' after the county name.
# - Edit the data such that the word ' County' is added to each county in the `covid` data.
#     - Run this function on all data EXCEPT index number 1556 (St. Louis city!)
# - Display your updated data frame.

# %%
covid.county = covid.county + ' County'
covid
# Out:
#             date             county    state     fips  cases  deaths  \
# 0     2020-06-15     Autauga County  Alabama   1001.0    368     6.0
# 1     2020-06-15     Baldwin County  Alabama   1003.0    383     9.0
# 2     2020-06-15     Barbour County  Alabama   1005.0    238     1.0
# 3     2020-06-15        Bibb County  Alabama   1007.0    111     1.0
# 4     2020-06-15      Blount County  Alabama   1009.0    116     1.0
# ...          ...                ...      ...      ...    ...     ...
# 3103  2020-06-15  Sweetwater County  Wyoming  56037.0     40     0.0
# 3104  2020-06-15       Teton County  Wyoming  56039.0    105     1.0
# 3105  2020-06-15       Uinta County  Wyoming  56041.0     73     0.0
# 3106  2020-06-15    Washakie County  Wyoming  56043.0     38     3.0
# 3107  2020-06-15      Weston County  Wyoming  56045.0      1     0.0
#
#       confirmed_cases  confirmed_deaths  probable_cases  probable_deaths
# 0               364.0               6.0             4.0              0.0
# 1               368.0               9.0            15.0              0.0
# 2               237.0               1.0             1.0              0.0
# 3               108.0               1.0             3.0              0.0
# 4               114.0               1.0             2.0              0.0
# ...               ...               ...             ...              ...
# 3103             32.0               NaN             8.0              NaN
# 3104             74.0               NaN            31.0              NaN
# 3105             65.0               NaN             8.0              NaN
# 3106             33.0               NaN             5.0              NaN
# 3107              1.0               NaN             0.0              NaN
#
# [3108 rows x 10 columns]

# %% [markdown]
# ## Merge dataframes.
# - Merge the `covid` dataframe and the `mo_counties` dataframe.
# - Be sure to subset the `covid` dataframe to only counties in Missouri because multiple states have the same county names.

# %%
covidMO = pd.merge(mo_counties, covid[covid.state == "Missouri"])
covidMO
# Out:
#                 county population area        date     state     fips  cases  \
# 0         Adair County      25607  568  2020-06-15  Missouri  29001.0     83
# 1        Andrew County      17291  435  2020-06-15  Missouri  29003.0     35
# 2      Atchison County       5685  545  2020-06-15  Missouri  29005.0      3
# 3       Audrain County      25529  693  2020-06-15  Missouri  29007.0    122
# 4         Barry County      35597  779  2020-06-15  Missouri  29009.0     14
# ..                 ...        ...  ...         ...       ...      ...    ...
# 105      Warren County      32513  432  2020-06-15  Missouri  29219.0     30
# 106  Washington County      25195  760  2020-06-15  Missouri  29221.0     13
# 107     Webster County      36202  593  2020-06-15  Missouri  29225.0     18
# 108       Worth County       2171  266  2020-06-15  Missouri  29227.0      4
# 109      Wright County      18815  682  2020-06-15  Missouri  29229.0     14
#
#      deaths  confirmed_cases  confirmed_deaths  probable_cases  \
# 0       0.0             83.0               0.0             NaN
# 1       0.0             35.0               0.0             NaN
# 2       0.0              3.0               0.0             NaN
# 3       1.0            122.0               1.0             NaN
# 4       0.0             14.0               0.0             NaN
# ..      ...              ...               ...             ...
# 105     0.0             30.0               0.0             NaN
# 106     1.0             13.0               1.0             NaN
# 107     0.0             18.0               0.0             NaN
# 108     0.0              4.0               0.0             NaN
# 109     0.0             14.0               0.0             NaN
#
#      probable_deaths
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ..               ...
# 105              NaN
# 106              NaN
# 107              NaN
# 108              NaN
# 109              NaN
#
# [110 rows x 12 columns]

# %% [markdown]
# ## Make a new variable.
#
# - Add a new column to your `covidMO` dataframe called density.
# - This variable is calculated by dividing the `population` variable by the `area` variable

# %%
covidMO['density'] = covidMO.population/covidMO.area

# %% [markdown]
# ## Create a scatter plot.
# - Make a scatter plot using `panda` attributes where you observe the relationship between `density` (x) and `cases`.
# - Add a title to the plot and include useful axis names.
# - Make the clustering of the points on the plot more visible by changing their transparency.

# %%
covidMO.plot.scatter(x='density',y = 'cases', alpha = .2)

plt.ylabel("Total Cases") 
plt.title("Cases of COVID-19 by Density")
plt.xlabel("Density")
# Out:
# Text(0.5, 0, 'Density')

# %% [markdown]
# ## Look at a subset of the data.
# - Load in the `seaborn` packages `as sns`.
# - Subset down to the following counties: 'St. Charles County' , 'St. Louis County'. 'St. Louis city County, 'Webster County', 'Bollinger County','Cole County','Madison County'.
# - Make another density/cases plot like you did above.
# - Add the argument `hue = 'county'` to your `scatterplot` call.
# - *Make sure to specify the data you are using in your call (you can subset the data here).*
# - Make sure the legend is outside of the plot.
#     - This plot is larger than our previous exposure to the `.legend` attribute. You can change the value to (1.5, 1) instead of (1,1).
# - Give the plot and axes useful names.

# %%
import seaborn as sns
sns.scatterplot(x= 'density',y = 'cases',hue='county', data = covidMO[covidMO.county.isin(['St. Charles County' , 'St. Louis County','St. Louis city County','Webster County','Bollinger County','Cole County','Madison County'])]).legend(bbox_to_anchor=(1.5,1))
plt.ylabel("Total Cases") 
plt.title("Cases of COVID-19 by Density")
plt.xlabel("Density")
# Out:
# Text(0.5, 0, 'Density')

# %% [markdown]
# ## Run the same plot with deaths instead of cases.

# %%
import seaborn as sns
sns.scatterplot(x= 'density',y = 'deaths',hue='county', data = covidMO[covidMO.county.isin(['St. Charles County' , 'St. Louis County','St. Louis city County','Webster County','Bollinger County','Cole County','Madison County'])]).legend(bbox_to_anchor=(1.5,1))
plt.ylabel("Total Deaths") 
plt.title("Cases of COVID-19 by Density")
plt.xlabel("Density")
# Out:
# Text(0.5, 0, 'Density')

# %% [markdown]
# ## Change the type of a column.
# - Change the `density` column to interger values (currently float) using the `.astype` attribute of `pandas`.

# %%
covidMO.density = covidMO.density.astype(int)

# %% [markdown]
# ## Run a regression.
# - Using the `statsmodels.api as smf` package run and display the regression 'cases ~ density' on the `covidMO` dataset.
#     - You can choose to add any variables if you believe they may be suitable controls

# %%
import statsmodels.api as smf
#We can do a linear regression with C() denoting that our data is categorical
lm = smf.formula.ols("cases ~ density", data = covidMO).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  cases   R-squared:                       0.448
# Model:                            OLS   Adj. R-squared:                  0.443
# Method:                 Least Squares   F-statistic:                     87.69
# Date:                Mon, 15 Jun 2020   Prob (F-statistic):           1.30e-15
# Time:                        15:57:07   Log-Likelihood:                -823.43
# No. Observations:                 110   AIC:                             1651.
# Df Residuals:                     108   BIC:                             1656.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     34.9659     42.840      0.816      0.416     -49.950     119.882
# density        0.7304      0.078      9.364      0.000       0.576       0.885
# ==============================================================================
# Omnibus:                      201.394   Durbin-Watson:                   2.712
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            26997.631
# Skew:                           7.557   Prob(JB):                         0.00
# Kurtosis:                      78.246   Cond. No.                         567.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## Run the same regression with deaths as the outcome variable.

# %%
lm = smf.formula.ols("deaths ~ density", data = covidMO).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 deaths   R-squared:                       0.338
# Model:                            OLS   Adj. R-squared:                  0.331
# Method:                 Least Squares   F-statistic:                     55.03
# Date:                Mon, 15 Jun 2020   Prob (F-statistic):           2.85e-11
# Time:                        15:57:08   Log-Likelihood:                -562.61
# No. Observations:                 110   AIC:                             1129.
# Df Residuals:                     108   BIC:                             1135.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4573      4.000      0.114      0.909      -7.472       8.386
# density        0.0540      0.007      7.418      0.000       0.040       0.068
# ==============================================================================
# Omnibus:                      208.915   Durbin-Watson:                   2.630
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            31149.890
# Skew:                           8.083   Prob(JB):                         0.00
# Kurtosis:                      83.839   Cond. No.                         567.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## 19. Save the `covidMO` dataset.
# - Save the `covidMO` dataset to a csv file.

# %%
covidMO.to_csv('covidMO.csv')

# %% [markdown]
# ## 20. Save your regression tables.
# - Import the `stargazer.stargazer` package.
# - Print out the HTML code using the `.render_html()` attribute of `Stargazer`.
#     - *Make sure to put brackets around your lm object for stargazer to process correctly*.
# - Put this code into 2 variables 'regresion1' for the 'cases~density' table and 'regression2' for the 'deaths~density' tables.
# - Save these two objects of HTML string code into 2 text files with the same name as the variables.

# %%
from stargazer.stargazer import Stargazer

lm1 = smf.formula.ols("cases ~ density", data = covidMO).fit()
lm2 = smf.formula.ols("deaths~density", data = covidMO).fit()

regression1 = Stargazer([lm1]).render_html()
regression2 = Stargazer([lm2]).render_html()
with open('regression1.txt', 'w') as f: # the 'w' in open let's the function know we are writing
    f.write(regression1)
with open('regression2.txt', 'w') as f: # the 'w' in open let's the function know we are writing
    f.write(regression2)

# %%
# Type your solution below this line:

# %% [markdown]
# # Thank you for taking my course!
# - Push this problem set to your 'Final Assignment' GitHub repository.
# - If you have the time please provide an evaluation for this course.
