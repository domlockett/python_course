# %% [markdown]
# # Day 4
#
# - So far we have learned how to wrangle data and display basic summaries of our data.
#     - Today we will finally look at some statistical analysis!
#     - Today's lecture assumes you have familiarity with analyzing regressions.

# %% [markdown]
# # Lecture 4.1: Anaylyzing data
#
# - In this lecture we will once again go through the process of importing, cleaning and merging data systematically.
#     - We will take our analyses one step further and go over how to run a regression and also how to display a regression.
# - **If you have any questions over the course of this lecture, please post them to the 'Day 4 Lecture Questions' assignment on the Canvas course page.**

# %% [markdown]
# ## Import the data
#
# - We will once again be relying on a scraper designed by Paul Boal which collects data from the [Clear Health Costs](https://clearhealthcosts.com/) website.
#     - Today we will be analyzing the cost of sleep procedures in four major cities in the United States.

# %%
#import the sleep csv
import pandas as pd
import numpy as np
sleep = pd.read_csv('sleep.csv')
sleep
# Out:
#       price                                           facility  \
# 0     650.0                                     iSleep Program
# 1     700.0                     New York Sleep Disorder Center
# 2     800.0                            Sleep Diagnostics of NY
# 3     800.0              Hackensack Sleep and Pulmonary Center
# 4     843.0  RWJBarnabas Health - Physician Enterprise Slee...
# ..      ...                                                ...
# 102  3499.0                   Texas Health Presbyterian Dallas
# 103  4965.0                  Baylor Scott and White Carrollton
# 104  4965.0  Sleep Study Center Baylor University Medical C...
# 105  4965.0                  Baylor Scott and White All Saints
# 106  4965.0                  Baylor Scott and White Waxahachie
#
#                                                address condition    zip  \
# 0                  1200 Waters Pl., Ste. 104, Bronx NY     sleep  10001
# 1               2951 Grand Concourse Ste. IA, Bronx NY     sleep  10001
# 2    69-39 Yellowstone Blvd., Ste. #1, Forest Hills NY     sleep  10001
# 3            170 Prospect Ave., Ste. 20, Hackensack NJ     sleep  10001
# 4                  593 Cranbury Rd., East Brunswick NJ     sleep  10001
# ..                                                 ...       ...    ...
# 102                    8200 Walnut Hill Ln., Dallas TX     sleep  75001
# 103                   4343 N. Josey Ln., Carrollton TX     sleep  75001
# 104  3600 Gaston Ave., Barnett Tower, Ste. 801, Dal...     sleep  75001
# 105                       1400 8th Ave., Fort Worth TX     sleep  75001
# 106                       2400 N. I-35E, Waxahachie TX     sleep  75001
#
#      radius      city
# 0        50  New York
# 1        50  New York
# 2        50  New York
# 3        50  New York
# 4        50  New York
# ..      ...       ...
# 102      50    Dallas
# 103      50    Dallas
# 104      50    Dallas
# 105      50    Dallas
# 106      50    Dallas
#
# [107 rows x 7 columns]

# %% [markdown]
# ## A little cleaning
# - Zero dollar values are not useful.

# %%
sleep = sleep[sleep.price != 0]

# %%
# import our visualization module and look at the distribution of prices

import seaborn as sns
from scipy import stats, integrate

sns.distplot(sleep.price)

# %% [markdown]
# ## Look at the distribution by city
#
# - San Francisco really pulls the data up, lets look with out San Francisco too.

# %%
sns.violinplot(data=sleep, y='price', x='city')

# %%
sns.boxplot(data=sleep, y='price', x='city') ## Dots outside the range determinde by seaborn package as outliers

# %%
sns.violinplot(data=sleep[sleep.city != "San Francisco"], y='price', x='city', cut = 0)

# %%
sns.violinplot(data=sleep[sleep.city == "San Francisco"], y='price', x='city', cut=0)

# %% [markdown]
# ## Exploring anomalies
#
# - Now we have some astronomical prices in San Francisco
#     - Let's try to figure out why by looking at our [source](https://clearhealthcosts.com/search/?query=sleep&zip_code=94016&radius=10&no_zero=1&submit=) data.
#     - So given that there are notes on the three highest values, perhaps we can remove those outliers.

# %%
sleep[sleep.city == "San Francisco"]
# Out:
#       price                                           facility  \
# 43    800.0                                           SleepMed
# 44   1000.0                         Golden State Sleep Centers
# 45   1140.0              California Center for Sleep Disorders
# 46   1175.0                          Contra Costa Sleep Center
# 47   1420.0                                    Sleep Health MD
# 48   1575.0                                   Bay Sleep Clinic
# 49   1600.0                            Tri-Valley Sleep Center
# 50   2250.0                       Sleep Medicine and Neurology
# 51   2323.0                 Sutter East Bay Medical Foundation
# 52   3122.0                       Palo Alto Medical Foundation
# 53   3122.0                     Fremont Sleep Disorders Center
# 54   3122.0                         The Sunnyvale Sleep Center
# 55   6550.0                   UCSF Benioff Children's Hospital
# 56  10000.0  Sleep Disorders Center at UCSF Medical Center ...
# 57  13195.0       Sleep Medicine Center at Stanford Healthcare
# 58  19440.0                  UCSF Medical Center at Mount Zion
#
#                                              address condition    zip  radius  \
# 43                  4335 Mangels Blvd., Fairfield CA     sleep  94016      50
# 44          39055 Hastings St., Ste. 106, Fremont CA     sleep  94016      50
# 45           985 Atlantic Ave., Ste. 250, Alameda CA     sleep  94016      50
# 46           1455 Montego, Ste. 102, Walnut Creek CA     sleep  94016      50
# 47                 173 N. Morrison Ave., San Jose CA     sleep  94016      50
# 48                       2939 Summit St., Oakland CA     sleep  94016      50
# 49    5201 Norris Canyon Rd., Ste. 120, San Ramon CA     sleep  94016      50
# 50           361 S. Monroe St., Ste. 30, San Jose CA     sleep  94016      50
# 51                      2500 Milvia St., Berkeley CA     sleep  94016      50
# 52                  795 El Camino Real, Palo Alto CA     sleep  94016      50
# 53           39650 Liberty St., Ste. 300, Fremont CA     sleep  94016      50
# 54         1309 S. Mary Ave., Ste. 200, Sunnyvale CA     sleep  94016      50
# 55                          747 52nd St., Oakland CA     sleep  94016      50
# 56         2330 Post St., Ste. 420, San Francisco CA     sleep  94016      50
# 57                 450 Broadway St., Redwood City CA     sleep  94016      50
# 58  1600 Divisadero St, San Francisco, CA 94115, USA     sleep  94016      50
#
#              city
# 43  San Francisco
# 44  San Francisco
# 45  San Francisco
# 46  San Francisco
# 47  San Francisco
# 48  San Francisco
# 49  San Francisco
# 50  San Francisco
# 51  San Francisco
# 52  San Francisco
# 53  San Francisco
# 54  San Francisco
# 55  San Francisco
# 56  San Francisco
# 57  San Francisco
# 58  San Francisco

# %%
sleep = sleep[sleep.price != 10000]
sleep = sleep[sleep.price != 13195]
sleep = sleep[sleep.price != 19440]

# %%
sns.violinplot(data=sleep, y='price', x='city')

# %%
sleep[sleep.city =="New York"]
# Out:
#      price                                           facility  \
# 0    650.0                                     iSleep Program
# 1    700.0                     New York Sleep Disorder Center
# 2    800.0                            Sleep Diagnostics of NY
# 3    800.0              Hackensack Sleep and Pulmonary Center
# 4    843.0  RWJBarnabas Health - Physician Enterprise Slee...
# 5    850.0                     New York Sleep Disorder Center
# 6    875.0                          Sleep Diagnostics of N.Y.
# 17                         29 E. 29th St., Bayonne NJ     sleep  10001
# 18              160 W. 26th St., 3rd Fl., New York NY     sleep  10001
# 19                      200A E. 62nd St., New York NY     sleep  10001
# 20                   1 Clara Maass Dr., Belleville NJ     sleep  10001
# 21          501 Kings Hwy. E., Ste. 105, Fairfield CT     sleep  10001
# 22              423 W. 55th St., 4th Fl., New York NY     sleep  10001
# 23                        100 E.77th St., New York NY     sleep  10001
# 24                 501 Seaview Ave., Staten Island NY     sleep  10001
# 25                      441 E. Tremont Ave., Bronx NY     sleep  10001
# 26                    1425 Bloomfield St., Hoboken NJ     sleep  10001
# 27                      16 Guion Pl., New Rochelle NY     sleep  10001
# 28                       300 Madison Ave., Madison NJ     sleep  10001
# 29                 11 E. 26th St., #1302, New York NY     sleep  10001
# 30                     5 Perryridge Rd., Greenwich CT     sleep  10001
# 31              425 E. 61st St., 5th Fl., New York NY     sleep  10001
# 32              425 E. 61st St., 5th Fl., New York NY     sleep  10001
# 33                593 Cranbury Rd., East Brunswick NJ     sleep  10001
# 34              423 W. 55th St., 4th Fl., New York NY     sleep  10001
# 35  69-39 Yellowstone Blvd., Ste. #1, Forest Hills NY     sleep  10001
# 36                1200 Waters Pl., Ste. 104, Bronx NY     sleep  10001
# 37                        89-40 135th St., Jamaica NY     sleep  10001
# 38                      200A E. 62nd St., New York NY     sleep  10001
# 39             2951 Grand Concourse Ste. IA, Bronx NY     sleep  10001
# 40                    1425 Bloomfield St., Hoboken NJ     sleep  10001
# 41              160 W. 26th St., 3rd Fl., New York NY     sleep  10001
# 42    12 Old Mamaroneck Rd., Ste. 1C, White Plains NY     sleep  10001
#
#     radius      city
# 0       50  New York
# 1       50  New York
# 2       50  New York
# 3       50  New York
# 4       50  New York
# 5       50  New York
# 6       50  New York
# 7       50  New York
# 8       50  New York
# 9       50  New York
# 10      50  New York
# 11      50  New York
# 12      50  New York
# 13      50  New York
# 14      50  New York
# 15      50  New York
# 16      50  New York
# 17      50  New York
# 18      50  New York
# 19      50  New York
# 20      50  New York
# 21      50  New York
# 22      50  New York
# 23      50  New York
# 24      50  New York
# 25      50  New York
# 26      50  New York
# 27      50  New York
# 28      50  New York
# 29      50  New York
# 30      50  New York
# 31      50  New York
# 32      50  New York
# 33      50  New York
# 34      50  New York
# 35      50  New York
# 36      50  New York
# 37      50  New York
# 38      50  New York
# 39      50  New York
# 40      50  New York
# 41      50  New York
# 42      50  New York

# %% [markdown]
# ## Simple linear regression
#
# - We know what our data looks like for price/city, but lets look at this with a regression analysis

# %%
# pip install this package
import statsmodels.api as smf

# %%
#We can do a linear regression with C() denoting that our data is categorical
lm = smf.formula.ols("price ~ C(city, Treatment(reference='New York'))", data = sleep).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.075
# Model:                            OLS   Adj. R-squared:                  0.047
# Method:                 Least Squares   F-statistic:                     2.699
# Date:                Sun, 31 May 2020   Prob (F-statistic):             0.0498
# Time:                        17:53:46   Log-Likelihood:                -892.31
# No. Observations:                 104   AIC:                             1793.
# Df Residuals:                     100   BIC:                             1803.
# Df Model:                           3
# Covariance Type:            nonrobust
# =============================================================================================================================
#                                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------
# Intercept                                                  1335.1395    200.332      6.665      0.000     937.687    1732.592
# C(city, Treatment(reference='New York'))[T.Dallas]          784.5405    330.395      2.375      0.019     129.045    1440.036
# C(city, Treatment(reference='New York'))[T.Miami]           361.2518    339.358      1.065      0.290    -312.024    1034.528
# C(city, Treatment(reference='New York'))[T.San Francisco]   910.9374    415.788      2.191      0.031      86.026    1735.849
# ==============================================================================
# Omnibus:                       19.699   Durbin-Watson:                   0.495
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.906
# Skew:                           1.124   Prob(JB):                     6.44e-06
# Kurtosis:                       3.679   Cond. No.                         4.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.075
# Model:                            OLS   Adj. R-squared:                  0.047
# Method:                 Least Squares   F-statistic:                     2.699
# Date:                Sun, 31 May 2020   Prob (F-statistic):             0.0498
# Time:                        17:53:46   Log-Likelihood:                -892.31
# No. Observations:                 104   AIC:                             1793.
# Df Residuals:                     100   BIC:                             1803.
# Df Model:                           3
# Covariance Type:            nonrobust
# =============================================================================================================================
#                                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------
# Intercept                                                  1335.1395    200.332      6.665      0.000     937.687    1732.592
# C(city, Treatment(reference='New York'))[T.Dallas]          784.5405    330.395      2.375      0.019     129.045    1440.036
# C(city, Treatment(reference='New York'))[T.Miami]           361.2518    339.358      1.065      0.290    -312.024    1034.528
# C(city, Treatment(reference='New York'))[T.San Francisco]   910.9374    415.788      2.191      0.031      86.026    1735.849
# ==============================================================================
# Omnibus:                       19.699   Durbin-Watson:                   0.495
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.906
# Skew:                           1.124   Prob(JB):                     6.44e-06
# Kurtosis:                       3.679   Cond. No.                         4.07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Neat exportable results?
# run pip install stargazer
from stargazer.stargazer import Stargazer


stargazer = Stargazer( [lm])
stargazer

# %%
stargazer.render_html()
# Out:
# '<table style="text-align:center"><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><td colspan="1"><em>Dependent variable:</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td></tr><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">C(city, Treatment(reference=\'New York\'))[T.Dallas]</td><td>784.54<sup>**</sup></td></tr><tr><td style="text-align:left"></td><td>(330.395)</td></tr><tr><td style="text-align:left">C(city, Treatment(reference=\'New York\'))[T.Miami]</td><td>361.252<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(339.358)</td></tr><tr><td style="text-align:left">C(city, Treatment(reference=\'New York\'))[T.San Francisco]</td><td>910.937<sup>**</sup></td></tr><tr><td style="text-align:left"></td><td>(415.788)</td></tr><tr><td style="text-align:left">Intercept</td><td>1335.14<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(200.332)</td></tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Observations</td><td>104.0</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.075</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.047</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>1313.663(df = 100.0)</td></tr><tr><td style="text-align: left">F Statistic</td><td>2.699<sup>**</sup>(df = 3.0; 100.0)</td></tr><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td>\n <td colspan="1" style="text-align: right">\n  <sup>*</sup>p&lt;0.1;\n  <sup>**</sup>p&lt;0.05;\n  <sup>***</sup>p&lt;0.01\n </td></tr></table>'

# %% [markdown]
# <table style="text-align:center"><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><td colspan="1"><em>Dependent variable:</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td></tr><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">C(city, Treatment(reference=\'New York\'))[T.Dallas]</td><td>784.54<sup>**</sup></td></tr><tr><td style="text-align:left"></td><td>(330.395)</td></tr><tr><td style="text-align:left">C(city, Treatment(reference=\'New York\'))[T.Miami]</td><td>361.252<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(339.358)</td></tr><tr><td style="text-align:left">C(city, Treatment(reference=\'New York\'))[T.San Francisco]</td><td>910.937<sup>**</sup></td></tr><tr><td style="text-align:left"></td><td>(415.788)</td></tr><tr><td style="text-align:left">Intercept</td><td>1335.14<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(200.332)</td></tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Observations</td><td>104.0</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.075</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.047</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>1313.663(df = 100.0)</td></tr><tr><td style="text-align: left">F Statistic</td><td>2.699<sup>**</sup>(df = 3.0; 100.0)</td></tr><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td>\n <td colspan="1" style="text-align: right">\n  <sup>*</sup>p&lt;0.1;\n  <sup>**</sup>p&lt;0.05;\n  <sup>***</sup>p&lt;0.01\n </td></tr></table>

# %%
stargazer.

# %%
## Plotting our regression

# %%
sns.catplot(data=sleep, x='city', y='price')
