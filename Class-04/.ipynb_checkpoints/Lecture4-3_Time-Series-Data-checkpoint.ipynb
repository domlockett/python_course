# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


d = pd.read_csv('/data/hhcaps.csv', quotechar='"')
d = d[d['Percent of patients who reported YES, they would definitely recommend the home health agency to friends and family'] != 'Not Available']
#d.replace(to_replace='Not Available', value=0, inplace=True)

# %%
d.dtypes
# Out:
# State                                                                                                                                 object
# CMS Certification Number (CCN)*                                                                                                        int64
# Provider Name                                                                                                                         object
# Address                                                                                                                               object
# City                                                                                                                                  object
# Zip                                                                                                                                    int64
# Phone                                                                                                                                  int64
# Type of Ownership                                                                                                                     object
# Offers Nursing Care Services                                                                                                            bool
# Offers Physical Therapy Services                                                                                                        bool
# Offers Occupational Therapy Services                                                                                                    bool
# Offers Speech Pathology Services                                                                                                        bool
# Offers Medical Social Services                                                                                                          bool
# Offers Home Health Aide Services                                                                                                        bool
# Date Certified                                                                                                                        object
# HHCAHPS Survey Summary Star Rating                                                                                                   float64
# Footnote HHCAHPS Survey Summary Star Rating                                                                                           object
# Star Rating for health team gave care in a professional way                                                                          float64
# Footnote for Star Rating for gave care in a professional way                                                                          object
# Percent of patients who reported that their home health team gave care in a professional way                                          object
# Footnote for percent of patients who reported that their home health team gave care in a professional way                             object
# Star Rating for health team communicated well with them                                                                              float64
# Footnote for Star Rating for communicated well with them                                                                              object
# Percent of patients who reported that their home health team communicated well with them                                              object
# Footnote for percent of patients who reported that their home health team communicated well with them                                 object
# Star Rating team discussed medicines, pain, and home safety                                                                          float64
# Footnote Star Rating discussed medicines, pain, home safety                                                                           object
# Percent of patients who reported that their home health team discussed medicines, pain, and home safety with them                     object
# Footnote for percent of patients who reported that their home health team discussed medicines, pain, and home safety with them        object
# Star Rating for how patients rated overall care from agency                                                                          float64
# Footnote for Star Rating for overall care from agency                                                                                 object
# Percent of patients who gave their home health agency a rating of 9 or 10 on a scale from 0 (lowest) to 10 (highest)                  object
# Footnote for percent of patients who gave their home health agency a rating of 9 or 10 on a scale from 0 (lowest) to 10 (highest)     object
# Percent of patients who reported YES, they would definitely recommend the home health agency to friends and family                    object
# Footnote for percent of patients who reported YES, they would definitely recommend the home health agency to friends and family       object
# Number of completed Surveys                                                                                                           object
# Footnote for number of completed surveys                                                                                              object
# Response rate                                                                                                                         object
# Footnote for response rate                                                                                                            object
# dtype: object

# %%
d['Date Certified'].head()
# Out:
# 1    1972-10-01 00:00:00
# 2    1973-01-18 00:00:00
# 3    1975-07-24 00:00:00
# 4    1975-09-04 00:00:00
# 5    1976-06-09 00:00:00
# Name: Date Certified, dtype: object

# %%
data = pd.DataFrame()
data['Year Certified'] = pd.to_datetime(d['Date Certified'].str[0:4] + '-01-01', format='%Y-%m-%d')
data['Percent Recommend'] = d['Percent of patients who reported YES, they would definitely recommend the home health agency to friends and family'].astype(float)


g = data.groupby(['Year Certified']).mean().plot(style='-')
g.set_ylim(0,100)
g

# %%
data = pd.DataFrame()
data['Date Certified'] = pd.to_datetime(d['Date Certified'], format='%Y-%m-%d')
data['Percent Recommend'] = d['Percent of patients who reported YES, they would definitely recommend the home health agency to friends and family'].astype(float)

g = data.groupby(['Date Certified']).mean().plot(style='.', alpha=.1)
g.set_ylim(0,100)
# Out:
# (0.0, 100.0)

# %%
recommend = pd.DataFrame()
recommend['Date Certified'] = pd.to_datetime(d['Date Certified'], format='%Y-%m-%d')
recommend['Percent Recommend'] = d['Percent of patients who reported YES, they would definitely recommend the home health agency to friends and family'].astype(float)

data = recommend.groupby(['Date Certified']).mean()

ma = data.rolling(20).mean()

mstd = data.rolling(20).std()

plt.figure()

plt.plot(data.index, data, 'k')

plt.plot(ma.index, ma, 'b')

#plt.fill_between(mstd.index, ma-2*mstd, ma+2*mstd, color='b', alpha=0.2)
