# %% [markdown]
# # Lecture 3-4: More Displays
#
# - This activity will have you display a dataset from [The World Health Organization](https://www.who.int/influenza/gisrs_laboratory/flunet/en/)
#
#     - This is world flu data for each week in 2019
#
# - **If you have any questions over the course of this lecture, please post them to the 'Day 3 Lecture Questions' assignment on the Canvas course page.**

# %% [markdown]
# ## Load the data.
#
# - Import the `panda`, `numpy`, `seaborn`, and `matplotlib` libraries.
# - Load in the file `flu2019` located in the data folder of this repository.
# - Name the panda dataframe `flu`.
# - Display `flu`.

# %%
#type your solution to the problem below this line:


import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

flu = pd.read_csv("data/flu2019.csv")

flu
# Out:
#        Country                      WHOREGION        FLUREGION  Year  Week  \
# 0      Algeria          African Region of WHO  Northern Africa  2019     1
# 1      Algeria          African Region of WHO  Northern Africa  2019     2
# 2      Algeria          African Region of WHO  Northern Africa  2019     3
# 3      Algeria          African Region of WHO  Northern Africa  2019     4
# 4      Algeria          African Region of WHO  Northern Africa  2019     5
# ...        ...                            ...              ...   ...   ...
# 8887  Viet Nam  Western Pacific Region of WHO  South-East Asia  2019    48
# 8888  Viet Nam  Western Pacific Region of WHO  South-East Asia  2019    49
# 8889  Viet Nam  Western Pacific Region of WHO  South-East Asia  2019    50
# 8890  Viet Nam  Western Pacific Region of WHO  South-East Asia  2019    51
# 8891  Viet Nam  Western Pacific Region of WHO  South-East Asia  2019    52
#
# ...

# %% [markdown]
# ## Subset and Display.
# - Make a new variable called `flu_usa`.
# - Use brackets to isolate the `United States of the America` in the dataset:  `data[data.variable == "Value"]`
# - Display your new dataframe.

# %%
flu_usa = flu[flu.Country == "United States of America"]

flu_usa
# Out:
#                        Country                      WHOREGION      FLUREGION  \
# 7384  United States of America  Region of the Americas of WHO  North America
# 7385  United States of America  Region of the Americas of WHO  North America
# 7386  United States of America  Region of the Americas of WHO  North America
# 7387  United States of America  Region of the Americas of WHO  North America
# 7388  United States of America  Region of the Americas of WHO  North America
# 7389  United States of America  Region of the Americas of WHO  North America
# 7390  United States of America  Region of the Americas of WHO  North America
# 7391  United States of America  Region of the Americas of WHO  North America
# 7392  United States of America  Region of the Americas of WHO  North America
# 7393  United States of America  Region of the Americas of WHO  North America
# 7394  United States of America  Region of the Americas of WHO  North America
# ...

# %% [markdown]
# ## Make a histogram.
#
# - Run the following code: `flu_usa[['INF_B','INF_A','SPEC_RECEIVED_NB']].hist(bins=5)`

# %%
flu_usa.
# Out:
#                        Country                      WHOREGION      FLUREGION  \
# 7384  United States of America  Region of the Americas of WHO  North America
# 7385  United States of America  Region of the Americas of WHO  North America
# 7386  United States of America  Region of the Americas of WHO  North America
# 7387  United States of America  Region of the Americas of WHO  North America
# 7388  United States of America  Region of the Americas of WHO  North America
# 7389  United States of America  Region of the Americas of WHO  North America
# 7390  United States of America  Region of the Americas of WHO  North America
# 7391  United States of America  Region of the Americas of WHO  North America
# 7392  United States of America  Region of the Americas of WHO  North America
# 7393  United States of America  Region of the Americas of WHO  North America
# 7394  United States of America  Region of the Americas of WHO  North America
# ...

# %%
#A histogram is a representation of the distribution of data. This function groups the values of all given Series in the DataFrame into bins and draws all bins in one matplotlib.
flu_usa[['INF_B','INF_A','SPEC_RECEIVED_NB']].hist(bins=3)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x151B5D78>,
# ...
#       dtype=object)

# %% [markdown]
# ## 4. Make a line plot.
#
# - Run the following code: `flu_usa.plot(x='SDATE', y=['INF_B','INF_A','SPEC_RECEIVED_NB','SPEC_PROCESSED_NB'])1`

# %%
flu_usa.plot(x='SDATE', y=['INF_B','INF_A','SPEC_RECEIVED_NB'])

# %% [markdown]
# ## 5. Scatter plot.
#
# - Run the following code:
#
# `axes = usa.plot.scatter(x='SPEC_RECEIVED_NB', y='INF_A', color='DarkRed', label='Influeza A')`
#
# `axes.set_ylabel('Positive Cases')`
#
# `axes.set_xlabel('Specimens Received')`

# %%
axes = flu_usa.plot.scatter(x='SPEC_RECEIVED_NB', y='INF_A', color='DarkRed', label='Influeza A')

axes.set_ylabel('Positive Cases')

axes.set_xlabel('Specimens Received')
# Out:
# Text(0.5, 0, 'Specimens Received')

# %% [markdown]
# ## 6. Combined plot
#
# - Run the following code:
#
# `axes = flu_usa.plot.scatter(x='SPEC_RECEIVED_NB', y='INF_A', color='DarkRed', label='Influeza A')`
#
# `axes = flu_usa.plot.scatter(x='SPEC_RECEIVED_NB', y='INF_B', color='DarkBlue', label='Influenza B', ax=axes)`
#
# `axes.set_ylabel('Positive Cases')`
#
# `axes.set_xlabel('Specimens Received')`

# %%
axes = flu_usa.plot.scatter(x='SPEC_RECEIVED_NB', y='INF_A', color='DarkRed', label='Influeza A')

axes = flu_usa.plot.scatter(x='SPEC_RECEIVED_NB', y='INF_B', color='DarkBlue', label='Influenza B', ax=axes)

axes.set_ylabel('Positive Cases')

axes.set_xlabel('Specimens Received')
# Out:
# Text(0.5, 0, 'Specimens Received')
