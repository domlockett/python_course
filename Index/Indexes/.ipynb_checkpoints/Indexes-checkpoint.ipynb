# %% [markdown]
# # Indexing
# - So indexing worked as I expected after suffering through my explanation for a while longer!
# - I have no clue why it wasn't working but about 20 minutes after we left I got it to work.
# - So an index is basically just what Python calls a row!
# - It refers to a position within an ordered list
#     - When our indexes are numbers we can just call on that numeric value.
#     - But we can change the index to a name. Or we can have multiple names.
#         - The key is the name of our index.
# - In the table below we have

# %%
import pandas as pd
import numpy as np
health_infect = pd.read_csv('https://domlockett.github.io/website/healthcare_infections.csv')

# %%
infect_index = pd.DataFrame.set_index(health_infect, keys=["State", "City"])
infect_index.loc['MO']
# Out:
#                  Facility ID                         Facility Name  \
# City
# HOUSTON               260024        TEXAS COUNTY MEMORIAL HOSPITAL
# JEFFERSON CITY        260047         CAPITAL REGION MEDICAL CENTER
# NEVADA                260061        NEVADA REGIONAL MEDICAL CENTER
# MOBERLY               260074       MOBERLY REGIONAL MEDICAL CENTER
# BRANSON               260094            COX MEDICAL CENTER BRANSON
# ...                      ...                                   ...
# LIBERTY               260177         NEW LIBERTY HOSPITAL DISTRICT
# TOWN AND COUNTRY      260108       MISSOURI BAPTIST MEDICAL CENTER
# MOBERLY               260074       MOBERLY REGIONAL MEDICAL CENTER
# BONNE TERRE           261315  PARKLAND HEALTH CENTER - BONNE TERRE
# CAPE GIRARDEAU        260110                       SOUTHEASTHEALTH
#
#                                                Address  ZIP Code  \
# City
# HOUSTON                     1333 SAM HOUSTON BOULEVARD     65483
# ...
